# %% [markdown]
# # Human feedback Crew
#
# The following code installs the required package for the YoutubeVideoSearch tool to function properly.

# %% [markdown]
# The following code suppresses warning messages to ensure the output is clean and focused on the essential results.

# %%
import warnings
import os
warnings.filterwarnings('ignore')
os.environ['PIP_ROOT_USER_ACTION'] = 'ignore'

# %% [markdown]
# Imports essential modules from CrewAI and initializes the YoutubeVideoSearchTool. Also, sets up environment variables to securely store API keys required for accessing external services.

# %%
from crewai import Agent, Task, Crew, Process
from crewai_tools import ScrapeWebsiteTool, SerperDevTool, YoutubeVideoSearchTool
from dotenv import load_dotenv

# Load All env variables storing the keys
load_dotenv()

# Create a search tool
search_tool = YoutubeVideoSearchTool(youtube_video_url='https://www.youtube.com/watch?v=R0ds4Mwhy-8')

# %% [markdown]
# Agents

# %%
# Define the research agent
researcher = Agent(
    role='Video Content Researcher',
    goal='Extract key insights from YouTube videos on AI advancements',
    backstory=(
        "You are a skilled researcher who excels at extracting valuable insights from video content. "
        "You focus on gathering accurate and relevant information from YouTube to support your team."
    ),
    verbose=True,
    tools=[search_tool],
    memory = True
)

# %%
# Define the writing agent
writer = Agent(
    role='Tech Article Writer',
    goal='Craft an article based on the research insights',
    backstory=(
        "You are an experienced writer known for turning complex information into engaging and accessible articles. "
        "Your work helps make advanced technology topics understandable to a broad audience."
    ),
    verbose=True,
    tools=[search_tool],  # The writer may also use the YouTube tool for additional context
    memory = True
)

# %% [markdown]
# Tasks

# %%
# Create the research task
research_task = Task(
    description=(
        "Research and extract key insights from YouTube regarding Educative. "
        "Compile your findings in a detailed summary."
    ),
    expected_output='A summary of the key insights from YouTube',
    agent=researcher
)

# %%
# Create the writing task
writing_task = Task(
    description=(
        "Using the summary provided by the researcher, write a compelling article on what is Educative. "
        "Ensure the article is well-structured and engaging for a tech-savvy audience."
    ),
    expected_output='A well-written article on Educative based on the YouTube video research.',
    agent=writer,
    human_input=True  # Allow for human feedback after the draft
)

# %% [markdown]
# Creates a crew and then kicks off the project.

# %%
from crewai import Crew

# Instantiate your crew with a sequential process
crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, writing_task],
    verbose=True,
    memory=True
)

# Get your crew to work!
result = crew.kickoff()

print("######################")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 408ce7c6-d646-467b-a3a5-6db7d85234cb                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Research and extract key insights from YouTube regarding Educative. Compile your findings in a detailed  │
# │  summary.                                                                                                       │
# │  ID: 6758d482-4aa0-4388-8eea-4eaf195a7391                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Video Content Researcher                                                                                │
# │                                                                                                                 │
# │  Task: Research and extract key insights from YouTube regarding Educative. Compile your findings in a detailed  │
# │  summary.                                                                                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#1) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: search_a_youtube_video_content                                                                           │
# │  Args: {'search_query': 'Educative'}                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool search_a_youtube_video_content executed with result: Relevant Content:
# my name is Fahim my brother name and I created educative to help developers learn new skills more efficiently we have helped millions of developers level up their careers and Tackle ...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#1) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: search_a_youtube_video_content                                                                           │
# │  Output: Relevant Content:                                                                                      │
# │  my name is Fahim my brother name and I created educative to help developers learn new skills more efficiently  │
# │  we have helped millions of developers level up their careers and Tackle technical interviews before starting   │
# │  educative name and I were software engineers at Facebook and Microsoft we were concerned by the lack of        │
# │  quality of learning resources created for developers by developers we found that existing material did a poor  │
# │  job at reintroducing Concepts that we hadn't focused on since University or it was buried in videos that       │
# │  wasted too much time the reality is that learning new programming skills is a lot like learning how to swim    │
# │  can you really do it effectively just by reading about it or watching someone else Mastery comes from diving   │
# │  in getting your hands dirty making mistakes and learning from them the same applies to coding this led to the  │
# │  creation of educative we wanted to build a platform that was not just Tech space to ensure depth and richness  │
# │  but also interactive to facilitate real-time learning and engagement at educative we have created an           │
# │  environment without any roadblocks to learning developers can learn and practice on the same platform without  │
# │  the need to install anything and we've Incorporated plenty of playgrounds quizzes and sandboxes to             │
# │                                                                                                                 │
# │   Ruby kubernetes and cotland if you are just starting your coding Journey we offer beginner courses with a     │
# │  structured approach to learning programming Basics plus we are adding new features all the time like AI        │
# │  assisted coaching so you will never get stuck on a problem again educative is the learning platform that I     │
# │  would have loved as a young developer because it makes learning interactive efficient and enjoyable happy      │
# │  [Music] learning                                                                                               │
# │                                                                                                                 │
# │   on the same platform without the need to install anything and we've Incorporated plenty of playgrounds        │
# │  quizzes and sandboxes to make the learning process Hands-On allowing developers to test their skills in real   │
# │  time now let's talk about technical interviews as someone who has personally conducted hundreds of software    │
# │  engineer interviews I know how challenging can it be to stand out from the competition but here's the secret   │
# │  interview in is a skill that can be developed just like any other skill interviewers at top companies are      │
# │  trained to look for hirable signals from candidates this is where strategic prep makes all the difference we   │
# │  have dozens of Hands-On courses covering coding interviews system design interviews API design interviews and  │
# │  more our resources are developed by Fang hiring managers to give you proven strategies for tackling real       │
# │  world interview questions but as a software developer the learning doesn't stop want you get the job with      │
# │  educative you can study new in demand Technologies like machine learning data science apis and cloud and       │
# │  brush up on all of the industry's most popular languages and Frameworks including python Ruby kubernetes and   │
# │  cotland if you are just starting your coding Journey we offer beginner courses with a structured approach to   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Video Content Researcher                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  My name is Fahim. My brother and I created Educative to help developers learn new skills more efficiently. We  │
# │  have helped millions of developers level up their careers and tackle technical interviews. Before starting     │
# │  Educative, my brother and I were software engineers at Facebook and Microsoft. We were concerned by the lack   │
# │  of quality learning resources created for developers by developers. Existing material often did a poor job at  │
# │  reintroducing concepts that we hadn't focused on since university, or it was buried in videos that wasted too  │
# │  much time.                                                                                                     │
# │                                                                                                                 │
# │  Learning new programming skills is like learning how to swim — mastery comes from diving in, getting your      │
# │  hands dirty, making mistakes, and learning from them. The same applies to coding. This philosophy led to the   │
# │  creation of Educative. We wanted to build a platform that was not just rich in technical depth but also        │
# │  interactive to facilitate real-time learning and engagement.                                                   │
# │                                                                                                                 │
# │  At Educative, developers can learn and practice on the same platform without needing to install anything. We   │
# │  have incorporated plenty of playgrounds, quizzes, and sandboxes to make the learning process hands-on,         │
# │  allowing developers to test their skills in real time.                                                         │
# │                                                                                                                 │
# │  Educative offers courses on beginner programming basics with a structured approach, plus new features like     │
# │  AI-assisted coaching, so learners never get stuck on a problem. The platform includes dozens of hands-on       │
# │  courses covering coding interviews, system design interviews, API design interviews, and more. Our resources   │
# │  are developed by FANG hiring managers, offering proven strategies for real-world interview questions.          │
# │                                                                                                                 │
# │  For ongoing development, Educative supports learning in in-demand technologies such as machine learning, data  │
# │  science, APIs, and cloud computing. It also offers courses covering popular languages and frameworks like      │
# │  Python, Ruby, Kubernetes, and Kotlin. Educative aims to make learning interactive, efficient, and enjoyable    │
# │  for developers at all stages of their career.                                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Research and extract key insights from YouTube regarding Educative. Compile your findings in a detailed  │
# │  summary.                                                                                                       │
# │  Agent: Video Content Researcher                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Using the summary provided by the researcher, write a compelling article on what is Educative. Ensure    │
# │  the article is well-structured and engaging for a tech-savvy audience.                                         │
# │  ID: f2f8a357-c8d6-401a-b131-fe207f36b4e4                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Tech Article Writer                                                                                     │
# │                                                                                                                 │
# │  Task: Using the summary provided by the researcher, write a compelling article on what is Educative. Ensure    │
# │  the article is well-structured and engaging for a tech-savvy audience.                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Tech Article Writer                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Educative: Revolutionizing How Developers Learn in the Digital Age                                             │
# │                                                                                                                 │
# │  In today’s fast-paced technology landscape, developers need to continuously upgrade their skills to stay       │
# │  relevant and advance their careers. Yet, the journey to mastering new programming skills is often hampered by  │
# │  outdated, inefficient learning resources. Enter Educative, a transformative platform founded by Fahim and his  │
# │  brother—both former software engineers at tech giants Facebook and Microsoft. Their mission: to create a       │
# │  developer-first learning ecosystem that is interactive, practical, and deeply aligned with the needs of        │
# │  modern coders.                                                                                                 │
# │                                                                                                                 │
# │  Why Educative Was Born                                                                                         │
# │                                                                                                                 │
# │  The origins of Educative lie in a shared frustration. Fahim and his brother noticed a glaring gap in the       │
# │  quality of educational resources available for developers. Existing materials either rehashed basic concepts   │
# │  in dry formats or depended heavily on passive video content that consumed too much time without fostering      │
# │  real understanding. The brothers believed coding education should be more like learning to swim—hands-on       │
# │  immersion, trial, error, and continuous practice. This philosophy is the cornerstone of Educative’s design.    │
# │                                                                                                                 │
# │  An Interactive, Code-First Learning Experience                                                                 │
# │                                                                                                                 │
# │  Unlike traditional platforms that split learning and practice, Educative integrates both seamlessly.           │
# │  Developers learn new concepts and instantly apply them in interactive coding environments directly within the  │
# │  platform—no software installations required. This real-time practice happens through a variety of coding       │
# │  playgrounds, quizzes, and sandboxes embedded throughout courses, enabling learners to experiment, debug, and   │
# │  master skills in the moment.                                                                                   │
# │                                                                                                                 │
# │  Comprehensive Course Offerings Spanning Beginner to Advanced                                                   │
# │                                                                                                                 │
# │  Educative caters to a wide spectrum of learners—from novices just starting with programming basics to          │
# │  seasoned engineers preparing for complex technical interviews. The platform features dozens of meticulously    │
# │  crafted courses on coding interviews, system design, API design, and more. Importantly, many of these courses  │
# │  are developed by FANG (Facebook, Amazon, Netflix, Google) hiring managers who bring insider insights and       │
# │  proven strategies into tackling real-world technical problems.                                                 │
# │                                                                                                                 │
# │  AI-Assisted Coaching: Personalized Learning Support                                                            │
# │                                                                                                                 │
# │  Recognizing that learners often get stuck on difficult problems, Educative has introduced AI-assisted          │
# │  coaching. This innovative feature provides timely hints, explanations, and guidance to help developers         │
# │  overcome hurdles without disrupting their learning flow. The AI coach acts as a personalized tutor, enhancing  │
# │  the efficiency and enjoyment of the learning journey.                                                          │
# │                                                                                                                 │
# │  Staying Ahead with In-Demand Technologies                                                                      │
# │                                                                                                                 │
# │  Educative keeps pace with evolving industry trends by offering courses in cutting-edge areas such as machine   │
# │  learning, data science, APIs, and cloud computing. Popular programming languages and frameworks like Python,   │
# │  Ruby, Kubernetes, and Kotlin are also deeply covered. This broad and relevant catalog empowers developers to   │
# │  continuously grow their skill sets, boost career prospects, and keep abreast of the latest technological       │
# │  advancements.                                                                                                  │
# │                                                                                                                 │
# │  A Platform Built by Developers, for Developers                                                                 │
# │                                                                                                                 │
# │  At its core, Educative’s strength stems from being created by developers who intimately understand the         │
# │  challenges of learning complex technical skills. Their firsthand experience informs every aspect of the        │
# │  platform—from course content to interactive features—making Educative uniquely effective for real-world        │
# │  developer needs.                                                                                               │
# │                                                                                                                 │
# │  In summary, Educative represents a new paradigm in tech education: immersive, efficient, interactive, and      │
# │  enjoyable. By bridging the gap between theory and practice and leveraging AI to customize learning, it helps   │
# │  millions of developers worldwide transform their potential into mastery. Whether you’re embarking on your      │
# │  coding journey or preparing for a high-stakes technical interview, Educative offers the tools, insights, and   │
# │  support to propel you forward in today’s competitive tech landscape.                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────── 💬 Human Feedback Required ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Provide feedback on the Final Result above.                                                                    │
# │                                                                                                                 │
# │  • If you are happy with the result, simply hit Enter without typing anything.                                  │
# │  • Otherwise, provide specific improvement requests.                                                            │
# │  • You can provide multiple rounds of feedback until satisfied.                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
from IPython.display import Markdown

# Convert the CrewOutput object to a Markdown string
result_markdown = result.raw

# Display the result as Markdown
Markdown(result_markdown)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from IPython.display import Markdown
#       2
#       3 # Convert the CrewOutput object to a Markdown string
# ----> 4 result_markdown = result.raw
#       5
#       6 # Display the result as Markdown
#       7 Markdown(result_markdown)
#
# NameError: name 'result' is not defined
